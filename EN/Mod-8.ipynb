# %% [markdown]
# # Module 8
# ## Tuple
#
# A tuple is an immutable, ordered data structure.
# **Immutable**: You cannot add elements to a tuple, or remove elements from it, once it has been created
# **Ordered**: The elements are stored in a specific order, and each element has an *index*, i.e. a position number, that tells its place within the tuple

# %% [markdown]
# ### Creating a Tuple and Reading its Elements
# A tuple can be created as follows:

# %%
tuple1 = (1,2,3)

# %% [markdown]
# The parentheses aren't required, though — the following also works:

# %%
tuple2 = 1,2,3

# %% [markdown]
# Since a tuple is ordered, each of its elements has an index. Using the index, we can access the value of a single element in the tuple, or the values of several consecutive elements.
# The syntax for this is the same as when working with lists.

# %%
# Create a new tuple
tuple3 = 1,2,3,4,5,6
# Print the value of the tuple's first element
print(tuple3[0])
# print the values of the tuple's first three elements
print(tuple3[0:3])
# Out:
# 1
# (1, 2, 3)

# %% [markdown]
# In the code field below, create a new tuple with the values 2,4,6,8,10

# %%
tuple4 = #add code here

# %% [markdown]
# print the value of the tuple's first element

# %%
print(#add here)

# %% [markdown]
# and the value of the last element

# %%
print(#add here)

# %% [markdown]
# and print the values of the three last elements

# %% [markdown]
# print(#add here)

# %% [markdown]
# ### Unpacking a Tuple into Variables
#
# The values of a tuple can be unpacked into variables as follows:

# %%
tuple5 = 1,2,3
(first, second, third) = tuple5

# %% [markdown]
# In the code above, the values of the tuple named tuple5 are unpacked into the variables first, second and third

# %% [markdown]
# Edit the code below so that the values of tuple6 are stored in the variables one, two, three

# %%
tuple6 = 4,5,6
#add here

# %% [markdown]
# ### Tuple as a Return Value
#
# When we want to return multiple values from a function, we can store the return values in a tuple, and then unpack them into variables when calling the function, as follows

# %%
def do_math(number1, number2):
    total = number1 + number2
    product = number1 * number2
    # store the values of the variables total and product in a tuple
    # and return it
    return (total, product)

# Call the function do_math, and unpack its return values
# into the variables total and product
(total, product) = do_math(1,2)

print(total)
print(product)
# Out:
# 3
# 2

# %% [markdown]
# Complete the division function below so that it returns the quotient and remainder of dividing number1 by number2, stored in a tuple
#
# In the main program, call the function, and unpack its return values into the variables quotient and remainder

# %%
def do_division(number1, number2):
    # Add code here

# Main program
#Add code here

print(quotient)
print(remainder)

# %% [markdown]
# ## Set
# A set is an unordered data structure.
# So the elements of a set aren't in any particular order, and they don't have indices.
#
# A set can contain a given value only once.
#
# ### Creating a Set
# A new set can be created as follows:

# %%
set1 = {1,2,3}

# %% [markdown]
# Unlike, for example, lists, we can't create a new empty set with the syntax set2 = {}.
# Instead, a new, empty set is created as follows:

# %%
set2 = set()

# %% [markdown]
# ### Adding and Removing Elements
# Elements can be added to, and removed from, a set while the program is running.
#
# New elements can be added using the add method:

# %%
set2.add("Matt")
print(set2)
# Out:
# {'Matt'}

# %% [markdown]
# Elements of a set can be removed based on their value as follows:

# %%
set2.remove("Matt")
print(set2)
# Out:
# set()

# %% [markdown]
# Create a new, empty set set3, and add three elements to it using the add method. Then print the set's values to the command line:

# %%
# Add code here

# %% [markdown]
# Then remove two of set3's elements using the remove method, and print the set's values again:

# %%
# add code here

# %% [markdown]
# ## Dictionary
#
# A dictionary is a data structure where data is stored as key-value pairs.
# ### Creating a Dictionary, Adding Key-Value Pairs, and Updating a Key's Value
#
# A new dictionary can be created as follows:

# %%
dict1 = {"Matt": 123, "Samantha": 345, "Jonas": 678}

# %% [markdown]
# The code above creates a dictionary with three keys: Matt, Samantha and Jonas, along with the value associated with each key.

# %% [markdown]
# We can look up the value of a key with the syntax:

# %%
dict1["Matt"]
# Out:
# 123

# %% [markdown]
# We can add new key-value pairs to a dictionary with the syntax

# %%
dict1["Kim"] = 111213

# %% [markdown]
# This adds a new key Kim to the dictionary dict1, with the value 111213

# %% [markdown]
# Add the key "Noa" to dict1, with the value 141515:

# %%
#Add code here

# %% [markdown]
# The same syntax can also be used to change the value of a key already in the dictionary:

# %%
dict1["Kim"] = 0000

# %% [markdown]
# The code above updates the value of the key Kim to 0000

# %% [markdown]
# Create a new dictionary dict2 to store users' passwords. The keys are usernames, and their values are the user's password. Store at least 3 key-value pairs in the dictionary.

# %%
dict2 = {#add code here}

# %% [markdown]
# Add two new key-value pairs to the dictionary

# %%
# Add code here

# %% [markdown]
# Change the values of two keys in the dictionary

# %%
# Add code here

# %% [markdown]
# ### Iterating Through a Dictionary
# We can check whether a given key is in a dictionary as follows:

# %%
if "Matt" in dict1:
    print(dict1["Matt"])
# Out:
# 123

# %% [markdown]
# Here, the code if "Matt" in dict1 checks whether "Matt" is a key in dict1.

# %% [markdown]
# We can also iterate through all the keys of a dictionary as follows:

# %%
for key in dict1:
    print(key)
# Out:
# Matt
# Samantha
# Jonas
# Kim

# %% [markdown]
# Print all the keys of the dict2 dictionary you created earlier:

# %%
# Add code here

# %% [markdown]
# Iterate through all of dict2's keys, and print their values:

# %%
# Add code here

# %% [markdown]
# ## Nested Data Structures
#
# The elements of a data structure don't have to hold primitive data such as single numbers or strings.
# We can also store data structures as elements of other data structures.
#
# For example, we can create a list in which each element is a dictionary, as follows:

# %%
students = [
    {
        "name": "Jane Doe",
        "Math": 2,
        "English": 3
    }, 
    {
            "name": "Sarah Smith",
            "Math": 5,
            "English": 1
    }, 
     {
                "name": "Sam Doe",
                "Math": 4,
                "English": 5
    }, 
]

# %% [markdown]
# Now we can access each dictionary using the list's indices. For example, we can print the dictionary contained in the first element of the list:

# %%
print(students[0])
# Out:
# {'name': 'Jane Doe', 'Math': 2, 'English': 3}

# %% [markdown]
# Or go through all the elements of the list one at a time:

# %%
for student in students:
    print(student)
# Out:
# {'name': 'Jane Doe', 'Math': 2, 'English': 3}
# {'name': 'Sarah Smith', 'Math': 5, 'English': 1}
# {'name': 'Sam Doe', 'Math': 4, 'English': 5}

# %% [markdown]
# If we then want to get a value out of a dictionary, we first fetch the correct dictionary from the list using the list index, and then get the value inside that dictionary based on its key:

# %%
students[0]["name"]
# Out:
# Jane Doe

# %% [markdown]
# Go through all the dictionaries in the students list, and print each one's name, along with their Math and English grades, one at a time:

# %%
# Add code here
