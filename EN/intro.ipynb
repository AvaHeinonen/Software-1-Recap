# %% [markdown]
# This is a Jupyter notebook.
# A Jupyter notebook lets you mix code and text.
# So this notebook has text sections like this one, as well as code sections like the code block below.
# You can run the code in a code block by clicking the button on its right side.

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# You can also edit the code in a code block. Some code blocks already have spots marked that you need to fill in for the code to work correctly.
# For example, in the code below, the spot marked #add here is where you need to edit the code so that it prints the words "hello world"

# %%
print(#Add here)
