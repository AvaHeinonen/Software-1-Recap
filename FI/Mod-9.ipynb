# %% [markdown]
# # Luokka, Olio, Alustaja
# ### Luokka ja luokan määrittely
#
# Olio-ohjelmoinnissa **luokka** määrittelee jonkin ohjelman konseptin ominaisuudet ja toiminnot.
#
# **Olio** taas on luokan ajonaikainen instanssi, eli luokan kuvaaman konseptin ilmentymä, jolla on luokassa määritellyt ominaisuudet ja toiminnot.
#
# Voimme esimerkiksi määritellä luokan pelaaja, jolla on ominaisuudet nimi, pelaaja id ja taso:

# %%
class Pelaaja:
    def __init__(self, nimi, taso, pelaaja_ID):
        self.nimi = nimi
        self.taso = taso
        self.pelaaja_ID = pelaaja_ID

# %% [markdown]
# voimme sitten luoda uusia pelaaja-olioita, eli pelaajaluokan ajonaikaisia ilmentymiä seuraavasti:

# %%
pelaaja1 = Pelaaja("Sandra", 0, 123)
pelaaja2 = Pelaaja("Kim", 1, 456)

# %% [markdown]
# ### Alustaja
# Alustaja on luokan metodi, joka ajetaan joka kerta kun luodaan uusi luokan olio.
#
# Alustaja ottaa parametrinä luotavan olion (self), sekä muut mahdolliset parametrit.
# Alustajan koodissa sitten määritellään olion ominaisuudet, ja annetaan niille arvot.
#
# Alustajan syntaksi on __init__(self, muut parametrit)
#
# Pelaajaluokkamme alustajassa:

# %%
class Pelaaja:
    def __init__(self, nimi, taso, pelaaja_ID):
        self.nimi = nimi
        self.taso = taso
        self.pelaaja_ID = pelaaja_ID

# %% [markdown]
# Alustaja ottaa parametreinään luotavan olion, sekä arvot sen nimelle, tasolle ja pelaaja ID:lle.
# Se luo sitten oliolle ominaisuudet nimi, taso ja ikä, ja tallentaa niihin parametreinä saamansa arvot.

# %% [markdown]
# Luo uusi luokka Kenttä, ja sille alustaja.
# Alustaja määrittelee Kentän olioille ominaisuuksiksi kenttä_ID, nimen, ja kuvauksen. Kaikki kolme annetaan parametreinä.

# %%
class Kentta:
    def __init__(#parametrit):
            #Koodisi tänne

# %% [markdown]
# Luo sitten kaksi uutta kenttä oliota, ja tulosta niiden nimet ja kuvaukset

# %%
# Koodisi tahan

# %% [markdown]
# ### Luokkien metodit
# Luokkien metodit ovat luokan sisällä määriteltyjä funktioita, joita voidaan kutsua luokan olioiden kautta.
#
# Voimme lisätä pelaaja luokkaamme metodin level_up, joka päivittää kyseisen pelaajaolion tason:

# %%
class Pelaaja:
    def __init__(self, nimi, taso, pelaaja_ID):
        self.nimi = nimi
        self.taso = taso
        self.pelaaja_ID = pelaaja_ID
    def level_up(self):
        self.taso += 1

# %% [markdown]
# Myös luokkien metodeihin annetaan aina ensimmäisenä parametrina self.
# Self viittaa siihen luokan olioon, joka metodia on kutsunut.

# %% [markdown]
# Voimme kutsua luokan metodeita olioiden kautta:

# %%
pelaaja3 = Pelaaja("Johan", 0, 123)
pelaaja3.level_up()
print(pelaaja3.taso)
# Out:
# 1

# %% [markdown]
# Muokkaa pelaajaluokkaa seuraavasti:
# Kun uusi pelaaja olio luodaan, sille määritellään ominaisuus esineet. Esineet on aluksi tyhjä lista.
# Lisää pelaajalle metodi lisaa_esine, joka ottaa parametrinaan esineen nimen, ja lisää sen pelaajaolion esineet listaan.

# %%
class Pelaaja:
    def __init__(self, nimi, taso, pelaaja_ID):
        self.nimi = nimi
        self.taso = taso
        self.pelaaja_ID = pelaaja_ID
        #Koodisi tänne
    def level_up(self):
        self.taso += 1
    def lisaa_esine(#koodisi tänne):
            #Koodisi tänne

# %% [markdown]
# Allaolevan koodin pitäisi sen jälkeen luoda uusi pelaaja, lisätä sen esinelistaan esine "miekka", ja tulostaa esinelistan sisältö:

# %%
pelaaja4 = Pelaaja("Sam", 1, 112233)
pelaaja4.lisaa_esine("miekka")
print(pelaaja4.esineet)

# %% [markdown]
# ### Luokkamuuttujat
#
# Luokilla voi myös olla muuttujia, jotka liittyvät luokkaan eivätkä sen tiettyyn olioon.
#
# Ne määritellään alustajan ulkopuolella:

# %%
class User:
    number_of_users = 0
    def __init__(self, name, id):
        self.name = name
        self.uid = id
        User.number_of_users += 1

# %% [markdown]
# Niitä voidaan sen jälkeen käyttää luokan sisällä, mutta self avainsanan sijaan niihin viitataan luokan nimellä, kuten ylemmässä esimerkissä.

# %% [markdown]
# Luo luokka Esine, joka kuvaa pelissä olevaa esinettä.
# Esineellä on nimi, kuvaus ja hinta. Kaikki kolme annetaan alustajaan parametreina.
# Esineellä on myös luokkamuuttuja esineiden_maara, joka tallentaa luotujen esineolioiden määrän.

# %%
class Esine:
    #koodisi tähän

# %% [markdown]
# Voit kokeilla luokkasi toimivuutta alla luomalla uusia esineitä, ja tulostamalla niiden ominaisuuksia:

# %%
# Testaa luokkaasi täällä
