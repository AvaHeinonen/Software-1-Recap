# %% [markdown]
# Tämä on Jupyter notebook.
# Jupyter notebook mahdollistaa sen, että koodia ja tekstiä voidaan sekoittaa.
# Tässä notebookissa on siis tekstiosioita kuten tämä, sekä koodiosioita kuten alla oleva koodiblokki.
# Voit ajaa koodiblokissa olevan koodin klikkaamalla sen oikealla sivulla olevaa painiketta.

# %%
print("Hei")
# Out:
# Hei

# %% [markdown]
# Voit myös editoida koodiblokin koodia. Joissain koodiblokeissa onkin valmiiksi merkittynä kohtia, jotka sinun tulee täyttää jotta koodi toimisi niinkuin pitää.
# Esim allaolevassa koodissa kohta #lisää tähän merkkaa kohtaa, johon sinun pitää muokata koodia siten että se tulostaa sanat "hei maailma"

# %%
print(#Lisää tähän)
